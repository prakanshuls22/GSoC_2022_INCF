# %%
# !pwd
# Out:
# /Users/prakanshulsaxena/GSoC

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v0 = [
("01866", 2.7986890432738267),
("02459", 2.319534131572903),
("01816", 2.7042235047864494),
("03004", 2.4677236590596747),
("03253", 2.735206656216791),
("01231", 2.824663238523294),
("00503", 2.844876584007031),
("02152", 2.6475525548196046),
("02015", 2.948557057100882),
("01046", 3.11794327021058)
]

# %%
v1=[
("01866", 2.8765774067547145),
("02459", 2.286472938219048),
("01816", 2.568448028074398),
("03004", 2.3614393743815922),
("03253", 2.578364421149399),
("01231", 2.91629791718466),
("00503", 2.8493322109908816),
("02152", 2.750571433709513),
("02015", 3.0263304318683666),
("01046", 2.9962474610954826)
]

# %%
v2 = [
("01866", 2.757699068849629),
("02459", 2.2282674983813293),
("01816", 2.456358198272282),
("03004", 2.358947343617434),
("03253", 2.8301568288457886),
("01231", 2.8058353200163513),
("00503", 2.731621388331079),
("02152", 2.6329637255333562),
("02015", 3.0624247842170447),
("01046", 3.0086253391697166)
]

# %%
v3=[
("01866", 2.6203008452239285),
("02459", 1.9313675878031522),
("01816", 2.7003478870954227),
("03004", 2.4218705687719932),
("03253", 2.3368365104706887),
("01231", 2.7720663584952536),
("00503", 2.7654854552873585),
("02152", 2.6727163975011403),
("02015", 3.0621041555953523),
("01046", 2.9495158413607787)
]

# %%
v3b=[
("01866", 1.6866525484893735),
("02459", 1.9181431430279823),
("01816", 2.274934900336887),
("03004", 1.959206301455486),
("03253", 2.525699371124052),
("01231", 2.1228902907444747),
("00503", 2.40010113587476),
("02152", 2.278697549332527),
("02015", 2.852418300079059),
("01046", 2.6374608718043695)
]

# %%
v3TESTING=[
("01866", 2.7419277623278213),
("02459", 1.9743938234245102),
("01816", 2.8865621009878004),
("03004", 2.3247892080883865),
("03253", 2.366068429652932),
("01231", 2.909376574408046),
("00503", 2.806864318847263),
("02152", 2.769360794997124),
("02015", 3.1081135369535193),
("01046", 3.0508870147591214)
]

# %%
v4=[
("01866", 2.430604114335292),
("02459", 1.9906611915124337),
("01816", 2.753031266448692),
("03004", 2.35175733580528),
("03253", 2.316372096947468),
("01231", 2.783033166628566),
("00503", 2.8686031097800315),
("02152", 2.741498976480354),
("02015", 3.019332098612639),
("01046", 2.8801359164006715)
]

# %%
v4b=[
("01866", 1.6429398573568421),
("02459", 1.9380381356455918),
("01816", 2.1897304048831687),
("03004", 2.251456022864777),
("03253", 2.6514886492190484),
("01231", 2.5041863710300007),
("00503", 2.2993653947147967),
("02152", 2.3932165821848113),
("02015", 2.6617435165738548),
("01046", 2.754443689334439)
]

# %%
v4test = [
("01866", 2.376147659636998),
("02459", 2.0178161289912238),
("01816", 2.7203400055284948),
("03004", 2.4158764444006917),
("03253", 2.148713352340862),
("01231", 2.8757756578807316),
("00503", 2.8170859168916405),
("02152", 2.7772004697253068),
("02015", 3.083532969407233),
("01046", 3.098716694552491)
]

# %%
v5 = [
("01866", 2.3426323274110388),
("02459", 2.1243815123328282),
("01816", 2.8323215137034747),
("03004", 2.1740063320497067),
("03253", 2.267449997709754),
("01231", 2.846679176482891),
("00503", 2.810783690440111),
("02152", 2.6941647912490705),
("02015", 3.087348451073598),
("01046", 2.9348666543141007)
]

# %%
v5b = [
("01866", 1.6486559843900437),
("02459", 1.8818867239556154),
("01816", 2.24800077723922),
("03004", 2.0676186672258803),
("03253", 2.5356665480675677),
("01231", 2.168043814280008),
("00503", 2.3850453089949357),
("02152", 2.302203743804941),
("02015", 2.870955063446529),
("01046", 2.6918649405370343)
]

# %%
vfinal_flipkey=[
("01866", 0.921634018078849),
("02459", 0.9355985275601567),
("01816", 1.1581137264038606),
("03004", 1.8418445185372803),
("03253", 1.273949873698674),
("01231", 1.9385222377433071),
("00503", 2.155699951215068),
("02152", 1.949379576879173),
("02015", 1.9791186381836365),
("01046", 1.5749947332366911)
]

# %%
vfinal=[
("01866", 1.146538030934348),
("02459", 1.2180686127840141),
("01816", 2.4625362004214506),
("03004", 2.7357218682563738),
("03253", 1.530682844302679),
("01231", 2.5215481141127225),
("00503", 2.3400548946369093),
("02152", 2.131035715388224),
("02015", 3.0083950426708057),
("01046", 1.8556526106682065)
]

# %%
vfinalLRnoflip_flipkey=[
("01866", 0.8780899179731586),
("02459", 0.9099096880735517),
("01816", 1.4892490323738394),
("03004", 1.5567805280309182),
("03253", 1.1022022374801892),
("01231", 1.8156629070453352),
("00503", 2.089099118540138),
("02152", 2.0972638596216195),
("02015", 1.9569920032251267),
("01046", 1.8179136118452186)
]

# %%
vfinalLRnoflip=[
("01866", 1.0869056148410674),
("02459", 1.5561141025770733),
("01816", 2.5648851228279823),
("03004", 2.7281267189621126),
("03253", 1.928696057839507),
("01231", 2.374070690010288),
("00503", 2.2475366341789216),
("02152", 2.542907510271505),
("02015", 2.844764247678719),
("01046", 1.9820934154335748)
]

# %%
vfinalUnif=[
("01866", 1.67810802202498),
("02459", 2.1955290452677994),
("01816", 2.5948800835383268),
("03004", 2.364784606457238),
("03253", 2.0007477202817907),
("01231", 2.315516573097037),
("00503", 2.5488187802978772),
("02152", 2.39433302152827),
("02015", 2.778365070983997),
("01046", 2.4469829738920343)
]

# %%
collection_of_versions = [vfinal,vfinalLRnoflip_flipkey,vfinal_flipkey,vfinalUnif,vfinalLRnoflip,v5b,v4b,v3b,v4test,v5,v0,v4,v3,v3TESTING,v2,v1]

# %%
len(collection_of_versions)
# Out:
# 16

# %%
versions = ['vfinal','vfinalLRnoflip_flipkey','vfinal_flipkey','vfinalUnif','vfinalLRnoflip','v5b','v4b','v3b','v4test','v5','v0','v4','v3','v3TESTING','v2','v1']

# %%
collection_acc_user=[]
for i in range(10):
    collection_acc_user.append([vfinal[i][1],vfinalLRnoflip_flipkey[i][1],vfinal_flipkey[i][1],vfinalUnif[i][1],vfinalLRnoflip[i][1],v5b[i][1],v4b[i][1],v3b[i][1],v4test[i][1],v5[i][1],v0[i][1],v4[i][1],v3[i][1],v3TESTING[i][1],v2[i][1],v1[i][1]])

# %%
len(collection_acc_user)
# Out:
# 10

# %%
average_collection = []
for x in collection_of_versions:
    sum_pv = 0
    for y in x:
        sum_pv+=y[1]
    average_pv = sum_pv/len(x)
    average_collection.append(average_pv)

# %%
len(average_collection)
# Out:
# 16

# %%
# x-axis and y-axis values for plotting
idx = [i for i in range(1,17)]
  
plt.figure(figsize=(35, 32))
# Plotting x-axis and y-axis
plt.plot(idx, collection_acc_user[0],marker='.',color='red',linestyle='solid', markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[1],marker='.',color='green',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[2],marker='.',color='blue',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[3],marker='.',color='orange',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[4],marker='.',color='purple',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[5],marker='.',color='brown',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[6],marker='.',color='red',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[7],marker='.',color='green',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[8],marker='.',color='blue',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[9],marker='.',color='orange',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, average_collection,marker='.',color='black',linewidth=7,linestyle='solid',markersize=12,markerfacecolor='red',markeredgecolor='red')
 
# naming of x-axis and y-axis
plt.xlabel("Versions")
plt.ylabel("MED")

plt.xticks(idx, versions)
# plt.xticks(np.arange(0, len(x)+1, 5))
plt.yticks(np.arange(min(temp_l), max(temp_l_m),0.1))

plt.grid(color = 'black', linestyle = '-', linewidth = 0.2)

plt.title("All Versions with AVG")
plt.savefig('/Users/prakanshulsaxena/GSoC/Result_Visualisations/all_versions_split_first_cv3_her.jpg')
plt.show()

# %%
temp_l = []
for x in collection_acc_user:
    temp_l.append(min(x))

# %%
temp_l
# Out:
# [0.8780899179731586,
#  0.9099096880735517,
#  1.1581137264038606,
#  1.5567805280309182,
#  1.1022022374801892,
#  1.8156629070453352,
#  2.089099118540138,
#  1.949379576879173,
#  1.9569920032251267,
#  1.5749947332366911]

# %%
temp_l_m = []
for x in collection_acc_user:
    temp_l_m.append(max(x))

# %%
temp_l_m
# Out:
# [2.8765774067547145,
#  2.319534131572903,
#  2.8865621009878004,
#  2.7357218682563738,
#  2.8301568288457886,
#  2.91629791718466,
#  2.8686031097800315,
#  2.7772004697253068,
#  3.1081135369535193,
#  3.11794327021058]

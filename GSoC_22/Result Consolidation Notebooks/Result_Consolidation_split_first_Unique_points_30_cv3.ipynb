# %%
# !pwd
# Out:
# /Users/prakanshulsaxena/GSoC

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v0 = [
("01866", 2.7009288450851625),
("02459", 2.312769969302442),
("01816", 2.463161052407791),
("03004", 2.5338313258509384),
("03253", 3.5931762871411888),
("01231", 2.318065399178389),
("00503", 2.965768551906275),
("02152", 2.902515008597842),
("02015", 3.312361301650195),
("01046", 3.4044421620993908)
]

# %%
v1=[
("01866", 3.757463546535401),
("02459", 3.0145209287124626),
("01816", 2.6739683506707355),
("03004", 3.108875900239058),
("03253", 3.6423888787455527),
("01231", 3.0167247641776096),
("00503", 2.0199140720510744),
("02152", 3.326294774504867),
("02015", 3.1889418295662852),
("01046", 3.750127346198187)
]

# %%
v2 = [
("01866", 3.0964562554091675),
("02459", 2.375042926681291),
("01816", 3.9317879315609883),
("03004", 2.7987599740840357),
("03253", 2.7467837266403317),
("01231", 2.3366433723713738),
("00503", 3.1336612566441904),
("02152", 3.7071980676144065),
("02015", 2.880187504339687),
("01046", 2.7722931469621295)
]

# %%
v3=[
("01866", 3.4791706628192447),
("02459", 2.4343719861997943),
("01816", 2.528585724872551),
("03004", 2.9020117790825917),
("03253", 2.7719740491503733),
("01231", 3.4025444757268404),
("00503", 3.1330827705064386),
("02152", 2.576593314437196),
("02015", 3.0151769142009934),
("01046", 3.441962736048398)
]

# %%
v3b=[
("01866", 2.665740227087658),
("02459", 1.7573311750845535),
("01816", 2.2685090839667192),
("03004", 3.0574552362707124),
("03253", 2.730846486641034),
("01231", 3.1720978660128663),
("00503", 3.0567414018718413),
("02152", 2.9538869111403603),
("02015", 2.8765971960309074),
("01046", 3.1073937099259394)
]

# %%
v3TESTING=[
("01866", 2.5022587839837738),
("02459", 2.4944968052776466),
("01816", 3.1581031911900883),
("03004", 3.818783655293624),
("03253", 2.0102721618335244),
("01231", 3.143117521916117),
("00503", 2.964395665581492),
("02152", 3.414587366198034),
("02015", 3.1081714457419594),
("01046", 3.2302443429626613)
]

# %%
v4=[
("01866", 2.637244845714479),
("02459", 3.33133499192239),
("01816", 2.744004812475131),
("03004", 2.886664057019966),
("03253", 2.697190155014555),
("01231", 3.4350374944099995),
("00503", 3.0437722071990674),
("02152", 2.7950170984054528),
("02015", 4.119322700155404),
("01046", 2.894779513469171)
]

# %%
v4b=[
("01866", 1.9238400064663301),
("02459", 2.607100478610326),
("01816", 2.0508169852184865),
("03004", 2.7899217068694173),
("03253", 3.1601963877477086),
("01231", 3.164461625754379),
("00503", 2.7645338442654284),
("02152", 3.531992166187366),
("02015", 3.3811562279591745),
("01046", 3.534965582639474)
]

# %%
v4test = [
("01866", 2.415335141985695),
("02459", 2.5866585781858973),
("01816", 2.7334265357151337),
("03004", 2.3733113504764356),
("03253", 2.935752348920703),
("01231", 3.008628709180213),
("00503", 3.613310113494185),
("02152", 3.0522384125087623),
("02015", 3.071186911091295),
("01046", 3.085678833283577)
]

# %%
v5 = [
("01866", 2.901555630652413),
("02459", 2.499674387333295),
("01816", 3.1960511697131824),
("03004", 3.603147486379852),
("03253", 2.4772514827448364),
("01231", 3.509953762741971),
("00503", 2.536763366218514),
("02152", 3.103480742372092),
("02015", 4.151290899559154),
("01046", 2.97971768608772)
]

# %%
v5b = [
("01866", 2.1763347790662824),
("02459", 1.7875228355424764),
("01816", 2.435420449018536),
("03004", 2.5468629448457776),
("03253", 4.118540975016165),
("01231", 2.2711030739332907),
("00503", 3.050274869920128),
("02152", 3.329742835384149),
("02015", 2.7308802544550312),
("01046", 2.5499529616672714)
]

# %%
vfinal_flipkey=[
("01866", 1.0147085402003255),
("02459", 1.203514204621489),
("01816", 1.1706614170884728),
("03004", 2.549862957659551),
("03253", 2.1665247766162867),
("01231", 2.4642471092904215),
("00503", 3.092923646984949),
("02152", 2.949024294249918),
("02015", 2.24148901213752),
("01046", 1.636928246126066)
]

# %%
vfinal=[
("01866", 1.2699379936232795),
("02459", 1.710808844287957),
("01816", 3.483801238567275),
("03004", 2.8119586841347637),
("03253", 2.2836076198894437),
("01231", 2.947894663227666),
("00503", 3.1352074331587305),
("02152", 2.768212010242478),
("02015", 3.6262522167716145),
("01046", 2.372422378517317)
]

# %%
vfinalLRnoflip_flipkey=[
("01866", 1.0982565295928928),
("02459", 0.9891045385699105),
("01816", 1.777733144784387),
("03004", 2.5115585843342063),
("03253", 1.2753364729467314),
("01231", 2.497502753600375),
("00503", 3.010661127591036),
("02152", 2.787369504037532),
("02015", 1.8922619898186066),
("01046", 2.0936953769444844)
]

# %%
vfinalLRnoflip=[
("01866", 2.254240432043515),
("02459", 1.7986792857368183),
("01816", 3.6583780228813176),
("03004", 2.859379870051971),
("03253", 2.5020937659346263),
("01231", 3.2471072560586296),
("00503", 2.2929032795244444),
("02152", 3.147052038834818),
("02015", 3.3110286375906144),
("01046", 2.242462055450234)
]

# %%
vfinalUnif=[
("01866", 3.2369187215621675),
("02459", 3.536420453005541),
("01816", 3.1219037501281015),
("03004", 3.0771812220701),
("03253", 2.3324156982835893),
("01231", 1.8895551158632904),
("00503", 3.3567629274114132),
("02152", 3.5487587868051027),
("02015", 3.211550243933253),
("01046", 2.523912054525884)
]

# %%
collection_of_versions = [vfinal,vfinalLRnoflip_flipkey,vfinal_flipkey,vfinalUnif,vfinalLRnoflip,v5b,v4b,v3b,v4test,v5,v0,v4,v3,v3TESTING,v2,v1]

# %%
len(collection_of_versions)
# Out:
# 16

# %%
versions = ['vfinal','vfinalLRnoflip_flipkey','vfinal_flipkey','vfinalUnif','vfinalLRnoflip','v5b','v4b','v3b','v4test','v5','v0','v4','v3','v3TESTING','v2','v1']

# %%
collection_acc_user=[]
for i in range(10):
    collection_acc_user.append([vfinal[i][1],vfinalLRnoflip_flipkey[i][1],vfinal_flipkey[i][1],vfinalUnif[i][1],vfinalLRnoflip[i][1],v5b[i][1],v4b[i][1],v3b[i][1],v4test[i][1],v5[i][1],v0[i][1],v4[i][1],v3[i][1],v3TESTING[i][1],v2[i][1],v1[i][1]])

# %%
len(collection_acc_user)
# Out:
# 10

# %%
average_collection = []
for x in collection_of_versions:
    sum_pv = 0
    for y in x:
        sum_pv+=y[1]
    average_pv = sum_pv/len(x)
    average_collection.append(average_pv)

# %%
len(average_collection)
# Out:
# 16

# %%
# x-axis and y-axis values for plotting
idx = [i for i in range(1,17)]
  
plt.figure(figsize=(35, 32))
# Plotting x-axis and y-axis
plt.plot(idx, collection_acc_user[0],marker='.',color='red',linestyle='solid', markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[1],marker='.',color='green',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[2],marker='.',color='blue',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[3],marker='.',color='orange',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[4],marker='.',color='purple',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[5],marker='.',color='brown',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[6],marker='.',color='red',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[7],marker='.',color='green',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[8],marker='.',color='blue',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[9],marker='.',color='orange',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, average_collection,marker='.',color='black',linewidth=7,linestyle='solid',markersize=12,markerfacecolor='red',markeredgecolor='red')
 
# naming of x-axis and y-axis
plt.xlabel("Versions")
plt.ylabel("MED")

plt.xticks(idx, versions)
# plt.xticks(np.arange(0, len(x)+1, 5))
plt.yticks(np.arange(min(temp_l), max(temp_l_m),0.1))

plt.grid(color = 'black', linestyle = '-', linewidth = 0.2)

plt.title("All Versions with AVG")
plt.savefig('/Users/prakanshulsaxena/GSoC/Result_Visualisations/all_versions_split_first_unique_points_30_cv3.jpg')
plt.show()

# %%
temp_l = []
for x in collection_acc_user:
    temp_l.append(min(x))

# %%
temp_l
# Out:
# [1.0147085402003255,
#  0.9891045385699105,
#  1.1706614170884728,
#  2.3733113504764356,
#  1.2753364729467314,
#  1.8895551158632904,
#  2.0199140720510744,
#  2.576593314437196,
#  1.8922619898186066,
#  1.636928246126066]

# %%
temp_l_m = []
for x in collection_acc_user:
    temp_l_m.append(max(x))

# %%
temp_l_m
# Out:
# [3.757463546535401,
#  3.536420453005541,
#  3.9317879315609883,
#  3.818783655293624,
#  4.118540975016165,
#  3.509953762741971,
#  3.613310113494185,
#  3.7071980676144065,
#  4.151290899559154,
#  3.750127346198187]

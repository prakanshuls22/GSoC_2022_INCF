# %%
# !pwd
# Out:
# /Users/prakanshulsaxena/GSoC

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v0 = [
("01866", 2.885447599633228),
("02459", 2.2720026737556096),
("01816", 2.7145362129853097),
("03004", 2.480687167372456),
("03253", 2.747002413531792),
("01231", 2.737896983311597),
("00503", 3.035899436864785),
("02152", 2.7433714728403467),
("02015", 3.0662047581733023),
("01046", 3.003270358536602)
]

# %%
v1=[
("01866", 2.8000402112424227),
("02459", 2.323763441184252),
("01816", 2.6711565442997594),
("03004", 2.459260733185256),
("03253", 2.7012125708807755),
("01231", 2.9891230266443567),
("00503", 2.8289433668039607),
("02152", 2.6328776182147484),
("02015", 2.9731231798487388),
("01046", 2.8860426716718637)
]

# %%
v2 = [
("01866", 2.847006781494115),
("02459", 2.3138013697043993),
("01816", 2.649580800074182),
("03004", 2.598890291451605),
("03253", 2.736917763207712),
("01231", 2.850664584211925),
("00503", 2.8701219029225684),
("02152", 2.8053185665148277),
("02015", 2.9094526663284443),
("01046", 2.955068206002518)
]

# %%
v3=[
("01866", 2.6726296142090153),
("02459", 1.9306974348663923),
("01816", 2.6855783564636595),
("03004", 2.4114266861206124),
("03253", 2.3831205559916473),
("01231", 3.0111155735875093),
("00503", 2.8523875754769867),
("02152", 2.670682728024736),
("02015", 3.1190700675896372),
("01046", 2.911986967804869)
]

# %%
v3b=[
("01866", 1.6175896312894764),
("02459", 1.9084927952729474),
("01816", 2.2436608316185596),
("03004", 2.0786424449511114),
("03253", 2.682506420611007),
("01231", 2.2726773682684636),
("00503", 2.405484680624388),
("02152", 2.295829118333189),
("02015", 2.8596152973298006),
("01046", 2.7219453537391276)
]

# %%
v3TESTING=[
("01866", 2.5938730880132557),
("02459", 1.8306865482839878),
("01816", 2.7612425359696933),
("03004", 2.265265289385795),
("03253", 2.277647260828343),
("01231", 2.828826178224532),
("00503", 2.8137911088307965),
("02152", 2.8132174718669876),
("02015", 3.074149182466483),
("01046", 2.9043445572868287)
]

# %%
v4=[
("01866", 2.424341524186572),
("02459", 2.1209194275667014),
("01816", 2.8644883919415185),
("03004", 2.4091198772283473),
("03253", 2.0943197733045733),
("01231", 2.8069544292484587),
("00503", 2.8773146749354077),
("02152", 2.7624524497103202),
("02015", 3.0210146492258163),
("01046", 3.0640019383563444)
]

# %%
v4b=[
("01866", 1.754788228592997),
("02459", 1.8638845391738645),
("01816", 2.1282531302162613),
("03004", 2.437693087309476),
("03253", 2.688343408783371),
("01231", 2.4417886186481788),
("00503", 2.1659974170266643),
("02152", 2.3916313449780944),
("02015", 2.7598171326178083),
("01046", 2.6720513758814866),
]

# %%
v4test = [
("01866", 2.6904563202400134),
("02459", 2.0350385234753894),
("01816", 2.6798543822852623),
("03004", 2.2751226616255007),
("03253", 2.2779589352580594),
("01231", 2.828090630461125),
("00503", 2.9570811686861793),
("02152", 2.748704500166926),
("02015", 3.0620092058127977),
("01046", 3.0270770936111546)
]

# %%
v5 = [
("01866", 2.399603527816539),
("02459", 2.258747104290552),
("01816", 2.6757879165561533),
("03004", 2.3461392178207623),
("03253", 2.1260548071743304),
("01231", 2.934748235983105),
("00503", 2.812197287828641),
("02152", 2.6997369125301396),
("02015", 3.0997590062300167),
("01046", 3.0689121487120796)
]

# %%
v5b = [
("01866", 1.7170218033264673),
("02459", 1.8324226779958015),
("01816", 2.2613643639724033),
("03004", 2.057792660843569),
("03253", 2.668971346446027),
("01231", 2.202096120224363),
("00503", 2.320896538978084),
("02152", 2.389219489395634),
("02015", 2.8155941676751555),
("01046", 2.727499460201897)
]

# %%
vfinal_flipkey=[
("01866", 0.9760910532289068),
("02459", 0.9677851005474984),
("01816", 1.2140886800415818),
("03004", 1.9674737883701312),
("03253", 1.123849457649591),
("01231", 1.8226743375326522),
("00503", 2.246196935833643),
("02152", 1.9104114824187353),
("02015", 2.0121975605417397),
("01046", 1.722522495074893)
]

# %%
vfinal=[
("01866", 1.3405210863750274),
("02459", 1.302425305192506),
("01816", 2.6136550515777515),
("03004", 2.6765721443981048),
("03253", 1.822441823235508),
("01231", 2.446606260926684),
("00503", 2.292770468088828),
("02152", 2.067774204064943),
("02015", 3.0470637455042526),
("01046", 1.8830907610452279)
]

# %%
vfinalLRnoflip_flipkey=[
("01866", 0.9262261549754643),
("02459", 0.9313812818635204),
("01816", 1.4929794453250727),
("03004", 1.7847495311606396),
("03253", 1.0256433362668553),
("01231", 1.7944325386560014),
("00503", 2.1507977850946998),
("02152", 1.9772516236105997),
("02015", 1.9860472411719272),
("01046", 1.7306382071793465)
]

# %%
vfinalLRnoflip=[
("01866", 1.1521589768313871),
("02459", 1.5128473196453316),
("01816", 2.6008899640938092),
("03004", 2.551977198926299),
("03253", 2.025433556671327),
("01231", 2.3149468037082226),
("00503", 2.468979768851636),
("02152", 2.4777645742775354),
("02015", 2.8662653035586008),
("01046", 1.9798239608627688)
]

# %%
vfinalUnif=[
("01866", 1.8547416838101645),
("02459", 2.2190006516726313),
("01816", 2.686036614649156),
("03004", 2.275519239120949),
("03253", 2.1647751910172137),
("01231", 2.3536908486362043),
("00503", 2.5469859762692106),
("02152", 2.4833056327511067),
("02015", 2.697587620416543),
("01046", 2.443896031630664)
]

# %%
collection_of_versions = [vfinal,vfinalLRnoflip_flipkey,vfinal_flipkey,vfinalUnif,vfinalLRnoflip,v5b,v4b,v3b,v4test,v5,v0,v4,v3,v3TESTING,v2,v1]

# %%
len(collection_of_versions)
# Out:
# 16

# %%
versions = ['vfinal','vfinalLRnoflip_flipkey','vfinal_flipkey','vfinalUnif','vfinalLRnoflip','v5b','v4b','v3b','v4test','v5','v0','v4','v3','v3TESTING','v2','v1']

# %%
collection_acc_user=[]
for i in range(10):
    collection_acc_user.append([vfinal[i][1],vfinalLRnoflip_flipkey[i][1],vfinal_flipkey[i][1],vfinalUnif[i][1],vfinalLRnoflip[i][1],v5b[i][1],v4b[i][1],v3b[i][1],v4test[i][1],v5[i][1],v0[i][1],v4[i][1],v3[i][1],v3TESTING[i][1],v2[i][1],v1[i][1]])

# %%
len(collection_acc_user)
# Out:
# 10

# %%
average_collection = []
for x in collection_of_versions:
    sum_pv = 0
    for y in x:
        sum_pv+=y[1]
    average_pv = sum_pv/len(x)
    average_collection.append(average_pv)

# %%
len(average_collection)
# Out:
# 16

# %%
# x-axis and y-axis values for plotting
idx = [i for i in range(1,17)]
  
plt.figure(figsize=(35, 32))
# Plotting x-axis and y-axis
plt.plot(idx, collection_acc_user[0],marker='.',color='red',linestyle='solid', markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[1],marker='.',color='green',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[2],marker='.',color='blue',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[3],marker='.',color='orange',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[4],marker='.',color='purple',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[5],marker='.',color='brown',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[6],marker='.',color='red',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[7],marker='.',color='green',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[8],marker='.',color='blue',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[9],marker='.',color='orange',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, average_collection,marker='.',color='black',linewidth=7,linestyle='solid',markersize=12,markerfacecolor='red',markeredgecolor='red')
 
# naming of x-axis and y-axis
plt.xlabel("Versions")
plt.ylabel("MED")

plt.xticks(idx, versions)
# plt.xticks(np.arange(0, len(x)+1, 5))
plt.yticks(np.arange(min(temp_l), max(temp_l_m),0.1))

plt.grid(color = 'black', linestyle = '-', linewidth = 0.2)

plt.title("All Versions with AVG")
plt.savefig('/Users/prakanshulsaxena/GSoC/Result_Visualisations/all_versions_3fold_split_first_30points.jpg')
plt.show()

# %%
temp_l = []
for x in collection_acc_user:
    temp_l.append(min(x))

# %%
temp_l
# Out:
# [0.9262261549754643,
#  0.9313812818635204,
#  1.2140886800415818,
#  1.7847495311606396,
#  1.0256433362668553,
#  1.7944325386560014,
#  2.1507977850946998,
#  1.9104114824187353,
#  1.9860472411719272,
#  1.722522495074893]

# %%
temp_l_m = []
for x in collection_acc_user:
    temp_l_m.append(max(x))

# %%
temp_l_m
# Out:
# [2.885447599633228,
#  2.323763441184252,
#  2.8644883919415185,
#  2.6765721443981048,
#  2.747002413531792,
#  3.0111155735875093,
#  3.035899436864785,
#  2.8132174718669876,
#  3.1190700675896372,
#  3.0689121487120796]

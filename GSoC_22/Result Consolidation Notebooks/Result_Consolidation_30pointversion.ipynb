# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v0 = [
("01866", 4.325869370811138),
("02459", 1.950880258548439),
("01816", 2.9021245962221087),
("03004", 2.455769838039603),
("03253", 3.5921224114283126),
("01231", 2.772562134256251),
("00503", 3.5962603132802187),
("02152", 3.08124098398183),
("02015", 3.3324139859029085),
("01046", 3.0568140000624098)
]

# %%
v1=[
("01866", 3.3001976172815604),
("02459", 2.4280172469992083),
("01816", 2.630160801407065),
("03004", 3.4156870217849216),
("03253", 2.678904258746485),
("01231", 2.5092687555654796),
("00503", 3.106686399252565),
("02152", 2.8119168910600503),
("02015", 3.592546956467346),
("01046", 3.4678110194001315)
]

# %%
v2 = [
("01866", 3.077530240366075),
("02459", 2.437998366439386),
("01816", 3.108716062453639),
("03004", 3.353884588581935),
("03253", 2.163355940399882),
("01231", 2.867838710296672),
("00503", 3.236435731814041),
("02152", 2.999207084919018),
("02015", 3.0641799258006674),
("01046", 3.212386131894458)
]

# %%
v3=[
("01866", 3.1274647187091844),
("02459", 2.6213013580468445),
("01816", 3.1241362773581485),
("03004", 3.282801277945487),
("03253", 2.838651643732886),
("01231", 3.516187515021391),
("00503", 3.4002507170741674),
("02152", 2.4185259082986286),
("02015", 3.1228240702812307),
("01046", 2.7396569502618275)
]

# %%
v3b=[
("01866", 2.171429969753911),
("02459", 2.486267820108464),
("01816", 3.1768008306632733),
("03004", 2.1368396765296875),
("03253", 2.4168045821310242),
("01231", 2.908911655252215),
("00503", 3.0856365036195967),
("02152", 2.6504445340861826),
("02015", 2.9784432801157243),
("01046", 3.3527381728805037)
]

# %%
v3TESTING=[
("01866", 3.0609831313873266),
("02459", 2.4885549671791507),
("01816", 3.024377197599491),
("03004", 2.7636240224648354),
("03253", 2.605880190294788),
("01231", 3.0955812149388353),
("00503", 3.7196593557605655),
("02152", 2.8578668040817963),
("02015", 3.682889540591322),
("01046", 2.8774009398775573)
]

# %%
v4=[
("01866", 3.152010101461515),
("02459", 2.8264479983205524),
("01816", 3.195864449445244),
("03004", 2.5982996134802554),
("03253", 2.4889322494671235),
("01231", 3.265447014291547),
("00503", 3.3263776278053845),
("02152", 3.174542818993343),
("02015", 3.503075702133702),
("01046", 2.4765377557508916)
]

# %%
v4b=[
("01866", 1.935205841561088),
("02459", 2.2250474061058028),
("01816", 2.3670391364554852),
("03004", 3.0121156797160245),
("03253", 2.65300980097652),
("01231", 3.2052073565776245),
("00503", 1.4560425972918376),
("02152", 2.6436497554025307),
("02015", 3.1846355681367737),
("01046", 3.192989039793216)
]

# %%
v4test = [
("01866", 2.888155163071482),
("02459", 3.0413006246285934),
("01816", 2.785830134153452),
("03004", 2.8068580605094278),
("03253", 2.5913900530580025),
("01231", 3.085470657012362),
("00503", 3.284922684902602),
("02152", 1.6082975895015954),
("02015", 3.959908619240024),
("01046", 2.796599912555345)
]

# %%
v5 = [
("01866", 3.5449737097139034),
("02459", 2.9585171296698993),
("01816", 2.7480549090370623),
("03004", 3.2711894216499258),
("03253", 3.096470267861273),
("01231", 2.6917916118560368),
("00503", 3.288826649072495),
("02152", 3.2582615104058856),
("02015", 3.2719522145305913),
("01046", 3.031553330479928)
]

# %%
v5b = [
("01866", 1.81425965201601),
("02459", 1.830005962851646),
("01816", 2.2913040726741474),
("03004", 2.660409677125993),
("03253", 2.8828579902938674),
("01231", 2.6948941066425562),
("00503", 2.3256507090389062),
("02152", 2.2968339324960017),
("02015", 3.036388765742574),
("01046", 2.733010154429094)
]

# %%
vfinal_flipkey=[
("01866", 2.1896178073463965),
("02459", 1.2854736461505014),
("01816", 1.922779039711572),
("03004", 2.042570981270294),
("03253", 2.07137205818696),
("01231", 2.2931058327479072),
("00503", 3.338649576677611),
("02152", 3.354461031875872),
("02015", 2.0919960868407403),
("01046", 2.4172588319714707)
]

# %%
vfinal=[
("01866", 1.1712583575410591),
("02459", 1.3961288549279185),
("01816", 2.0945021528184133),
("03004", 3.1763291235464752),
("03253", 2.5612879833779103),
("01231", 2.528116465525229),
("00503", 2.2448965724473333),
("02152", 3.5968969818473226),
("02015", 3.226223964825201),
("01046", 1.6780899248783163)
]

# %%
vfinalLRnoflip_flipkey=[
("01866", 1.2115559859222635),
("02459", 1.2856071716955682),
("01816", 1.7200104898014736),
("03004", 1.8483406989410749),
("03253", 1.1486164674841834),
("01231", 2.4190855645001133),
("00503", 3.1231803057368737),
("02152", 1.732363164807867),
("02015", 1.8754394272330468),
("01046", 2.1279368750797594)
]

# %%
vfinalLRnoflip=[
("01866", 1.1925504553978326),
("02459", 1.6996971287568756),
("01816", 3.0646264551558065),
("03004", 2.6821485809844483),
("03253", 2.8969395398904174),
("01231", 2.8123765610713107),
("00503", 2.005457438025686),
("02152", 3.04003353487879),
("02015", 3.1429001044844256),
("01046", 1.082421908920008)
]

# %%
vfinalUnif=[
("01866", 1.5186710360679074),
("02459", 3.061038980408064),
("01816", 2.8742113955539454),
("03004", 2.228442227882972),
("03253", 2.3947692514407715),
("01231", 2.029758529635986),
("00503", 2.2030770463199283),
("02152", 3.1373108912940566),
("02015", 3.6944799903046146),
("01046", 2.40765799569)
]

# %%
collection_of_versions = [vfinal,vfinalLRnoflip_flipkey,vfinal_flipkey,vfinalUnif,vfinalLRnoflip,v5b,v4b,v3b,v4test,v5,v0,v4,v3,v3TESTING,v2,v1]

# %%
len(collection_of_versions)
# Out:
# 16

# %%
versions = ['vfinal','vfinalLRnoflip_flipkey','vfinal_flipkey','vfinalUnif','vfinalLRnoflip','v5b','v4b','v3b','v4test','v5','v0','v4','v3','v3TESTING','v2','v1']

# %%
collection_acc_user=[]
for i in range(10):
    collection_acc_user.append([vfinal[i][1],vfinalLRnoflip_flipkey[i][1],vfinal_flipkey[i][1],vfinalUnif[i][1],vfinalLRnoflip[i][1],v5b[i][1],v4b[i][1],v3b[i][1],v4test[i][1],v5[i][1],v0[i][1],v4[i][1],v3[i][1],v3TESTING[i][1],v2[i][1],v1[i][1]])

# %%
len(collection_acc_user)
# Out:
# 10

# %%
average_collection = []
for x in collection_of_versions:
    sum_pv = 0
    for y in x:
        sum_pv+=y[1]
    average_pv = sum_pv/len(x)
    average_collection.append(average_pv)

# %%
len(average_collection)
# Out:
# 16

# %%
min(min(collection_acc_user))
# Out:
# 1.1712583575410591

# %%
# x-axis and y-axis values for plotting
idx = [i for i in range(1,17)]
  
plt.figure(figsize=(35, 32))
# Plotting x-axis and y-axis
plt.plot(idx, collection_acc_user[0],marker='.',color='red',linestyle='solid', markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[1],marker='.',color='green',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[2],marker='.',color='blue',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[3],marker='.',color='orange',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[4],marker='.',color='purple',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[5],marker='.',color='brown',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[6],marker='.',color='red',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[7],marker='.',color='green',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[8],marker='.',color='blue',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[9],marker='.',color='orange',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, average_collection,marker='.',color='black',linewidth=7,linestyle='solid',markersize=12,markerfacecolor='red',markeredgecolor='red')
 
# naming of x-axis and y-axis
plt.xlabel("Versions")
plt.ylabel("MED")

plt.xticks(idx, versions)
# plt.xticks(np.arange(0, len(x)+1, 5))
plt.yticks(np.arange(min(temp_lauda), max(temp_lauda_m),0.1))

plt.grid(color = 'black', linestyle = '-', linewidth = 0.2)

plt.title("All Versions with AVG")
plt.savefig('/Users/prakanshulsaxena/GSoC/Result_Visualisations/all_versions_5fold split later_30points.jpg')
plt.show()

# %%
temp_lauda = []
for x in collection_acc_user:
    temp_lauda.append(min(x))

# %%
temp_lauda
# Out:
# [1.1712583575410591,
#  1.2854736461505014,
#  1.7200104898014736,
#  1.8483406989410749,
#  1.1486164674841834,
#  2.029758529635986,
#  1.4560425972918376,
#  1.6082975895015954,
#  1.8754394272330468,
#  1.082421908920008]

# %%
min(collection_acc_user)
# Out:
# [1.1712583575410591,
#  1.2115559859222635,
#  2.1896178073463965,
#  1.5186710360679074,
#  1.1925504553978326,
#  1.81425965201601,
#  1.935205841561088,
#  2.171429969753911,
#  2.888155163071482,
#  3.5449737097139034,
#  4.325869370811138,
#  3.152010101461515,
#  3.1274647187091844,
#  3.0609831313873266,
#  3.077530240366075,
#  3.3001976172815604]

# %%
temp_lauda_m = []
for x in collection_acc_user:
    temp_lauda_m.append(max(x))

# %%
temp_lauda_m
# Out:
# [4.325869370811138,
#  3.061038980408064,
#  3.195864449445244,
#  3.4156870217849216,
#  3.5921224114283126,
#  3.516187515021391,
#  3.7196593557605655,
#  3.5968969818473226,
#  3.959908619240024,
#  3.4678110194001315]

# %%
# !pwd
# Out:
# /Users/prakanshulsaxena/GSoC

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v0 = [
("01866", 2.68641342769778),
("02459", 2.384964241995626),
("01816", 2.590040370756417),
("03004", 2.402211863164731),
("03253", 2.761270378427103),
("01231", 2.8489686339330427),
("00503", 2.742993886346912),
("02152", 2.8307172942649266),
("02015", 3.0045470516082107),
("01046", 3.0373924123727662)
]

# %%
v1=[
("01866", 2.6652842149376346),
("02459", 2.228901833833138),
("01816", 2.7243929800392213),
("03004", 2.479924464623465),
("03253", 2.7227991843189945),
("01231", 2.934415450486464),
("00503", 2.9281748085779493),
("02152", 2.720390412641709),
("02015", 3.0110766522634806),
("01046", 2.9930760049212326)
]

# %%
v2 = [
("01866", 2.7853841580284713),
("02459", 2.477749726324046),
("01816", 2.5391650155276313),
("03004", 2.531556825814696),
("03253", 2.646768855620663),
("01231", 2.81448391430741),
("00503", 2.8561391878721007),
("02152", 2.710453747108663),
("02015", 2.8515958555867003),
("01046", 2.895479769596288)
]

# %%
v3=[
("01866", 2.75599753333426),
("02459", 1.9632244762918913),
("01816", 2.5548566156670045),
("03004", 2.39268529407356),
("03253", 2.2952334259073504),
("01231", 2.803414379617691),
("00503", 2.8770840696849667),
("02152", 2.5793248612636006),
("02015", 3.117618633786171),
("01046", 2.916917902885609)
]

# %%
v3b=[
("01866", 1.5095644585034549),
("02459", 1.8308010994493316),
("01816", 2.3127699529605263),
("03004", 1.9854741920348415),
("03253", 2.6655960625075967),
("01231", 2.448582884946897),
("00503", 2.4177344204271574),
("02152", 2.313609610568278),
("02015", 2.8324697828628187),
("01046", 2.774491089247277)
]

# %%
v3TESTING=[
("01866", 2.643648481467777),
("02459", 1.9610168952623936),
("01816", 2.5875020807040996),
("03004", 2.3324934331117757),
("03253", 2.355436927834753),
("01231", 2.8861960740817363),
("00503", 2.855069654974642),
("02152", 2.734179232952849),
("02015", 3.2587243296976394),
("01046", 2.966708071295112)
]

# %%
v4=[
("01866", 2.4710120176959496),
("02459", 2.1083350325434105),
("01816", 2.8669496275585327),
("03004", 2.275462773480984),
("03253", 2.2888442620176344),
("01231", 2.847702240134862),
("00503", 2.916883053454298),
("02152", 2.7109926871155756),
("02015", 2.98245149720213),
("01046", 3.0300826774436445)
]

# %%
v4b=[
("01866", 1.7193905263821254),
("02459", 1.8416577573970325),
("01816", 2.2394182565916667),
("03004", 2.267219697393248),
("03253", 2.651879176201367),
("01231", 2.5715778456825222),
("00503", 2.338429153105327),
("02152", 2.3441692550541138),
("02015", 2.8922690806880285),
("01046", 2.665426232149063)
]

# %%
v4test = [
("01866", 2.538164813477763),
("02459", 2.1279780398770463),
("01816", 2.682957094359529),
("03004", 2.2648818258686387),
("03253", 2.1656908458054778),
("01231", 2.9654173366887515),
("00503", 2.818566753858751),
("02152", 2.6969840428838774),
("02015", 3.1377982675349596),
("01046", 3.011435519358428)
]

# %%
v5 = [
            ("01866", 2.4520096209984303),
            ("02459", 2.1040624151994702),
            ("01816", 2.84354892904303),
            ("03004", 2.3656804626351438),
            ("03253", 2.1683500472336945),
            ("01231", 2.8463056460475618),
            ("00503", 2.979888039013298),
            ("02152", 2.7275622532244803),
            ("02015", 3.0640079592135083),
            ("01046", 3.0355536712021585)
]

# %%
v5b = [
("01866", 1.6317171091067084),
("02459", 1.8805373966872887),
("01816", 2.3180223783457437),
("03004", 2.079625022832659),
("03253", 2.5782786718410113),
("01231", 2.217408534248138),
("00503", 2.239233690503441),
("02152", 2.2454869183202897),
("02015", 2.825561262675249),
("01046", 2.564711274643983)
]

# %%
vfinal_flipkey=[
("01866", 0.9792245576425911),
("02459", 0.9218747424416293),
("01816", 1.2113041318319664),
("03004", 1.9859404672489707),
("03253", 1.2853216248441912),
("01231", 1.801721025736721),
("00503", 2.283030691201764),
("02152", 1.8709919842373945),
("02015", 2.060202248380251),
("01046", 1.6339886679310816)
]

# %%
vfinal=[
("01866", 1.1821545898922934),
("02459", 1.278207079923403),
("01816", 2.4690048060344623),
("03004", 2.7318557087139315),
("03253", 1.724725953457094),
("01231", 2.608515947325349),
("00503", 2.558358779310368),
("02152", 2.096364725088923),
("02015", 3.0092194928066847),
("01046", 1.9285026282587394)
]

# %%
vfinalLRnoflip_flipkey=[
("01866", 0.9336420086359768),
("02459", 0.8869755604734643),
("01816", 1.551430286868546),
("03004", 1.686880435058986),
("03253", 1.0939057697963044),
("01231", 1.8448705826436553),
("00503", 1.9828801945997383),
("02152", 2.0375753990093037),
("02015", 1.7429324711031935),
("01046", 1.736506296359844)
]

# %%
vfinalLRnoflip=[
("01866", 1.2750501509026924),
("02459", 1.539509813490538),
("01816", 2.8060677416291253),
("03004", 2.561100720143986),
("03253", 2.110576431290567),
("01231", 2.524933736000608),
("00503", 2.357916951139345),
("02152", 2.4887015079614203),
("02015", 2.857442412256931),
("01046", 1.9955514071083564)
]

# %%
vfinalUnif=[
("01866", 1.8864023387182347),
("02459", 2.2381517726029285),
("01816", 2.654353586070454),
("03004", 2.3683316836322827),
("03253", 1.9945538576886068),
("01231", 2.338631289878008),
("00503", 2.5473484034806666),
("02152", 2.5731568532251163),
("02015", 2.675163126180664),
("01046", 2.460408758132209)
]

# %%
collection_of_versions = [vfinal,vfinalLRnoflip_flipkey,vfinal_flipkey,vfinalUnif,vfinalLRnoflip,v5b,v4b,v3b,v4test,v5,v0,v4,v3,v3TESTING,v2,v1]

# %%
len(collection_of_versions)
# Out:
# 16

# %%
versions = ['vfinal','vfinalLRnoflip_flipkey','vfinal_flipkey','vfinalUnif','vfinalLRnoflip','v5b','v4b','v3b','v4test','v5','v0','v4','v3','v3TESTING','v2','v1']

# %%
collection_acc_user=[]
for i in range(10):
    collection_acc_user.append([vfinal[i][1],vfinalLRnoflip_flipkey[i][1],vfinal_flipkey[i][1],vfinalUnif[i][1],vfinalLRnoflip[i][1],v5b[i][1],v4b[i][1],v3b[i][1],v4test[i][1],v5[i][1],v0[i][1],v4[i][1],v3[i][1],v3TESTING[i][1],v2[i][1],v1[i][1]])

# %%
len(collection_acc_user)
# Out:
# 10

# %%
average_collection = []
for x in collection_of_versions:
    sum_pv = 0
    for y in x:
        sum_pv+=y[1]
    average_pv = sum_pv/len(x)
    average_collection.append(average_pv)

# %%
len(average_collection)
# Out:
# 16

# %%
# x-axis and y-axis values for plotting
idx = [i for i in range(1,17)]
  
plt.figure(figsize=(35, 32))
# Plotting x-axis and y-axis
plt.plot(idx, collection_acc_user[0],marker='.',color='red',linestyle='solid', markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[1],marker='.',color='green',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[2],marker='.',color='blue',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[3],marker='.',color='orange',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[4],marker='.',color='purple',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[5],marker='.',color='brown',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[6],marker='.',color='red',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[7],marker='.',color='green',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[8],marker='.',color='blue',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[9],marker='.',color='orange',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, average_collection,marker='.',color='black',linewidth=7,linestyle='solid',markersize=12,markerfacecolor='red',markeredgecolor='red')
 
# naming of x-axis and y-axis
plt.xlabel("Versions")
plt.ylabel("MED")

plt.xticks(idx, versions)
# plt.xticks(np.arange(0, len(x)+1, 5))
plt.yticks(np.arange(min(temp_l), max(temp_l_m),0.1))

plt.grid(color = 'black', linestyle = '-', linewidth = 0.2)

plt.title("All Versions with AVG")
plt.savefig('/Users/prakanshulsaxena/GSoC/Result_Visualisations/all_versions_split_first_cv5_her.jpg')
plt.show()

# %%
temp_l = []
for x in collection_acc_user:
    temp_l.append(min(x))

# %%
temp_l
# Out:
# [0.9336420086359768,
#  0.8869755604734643,
#  1.2113041318319664,
#  1.686880435058986,
#  1.0939057697963044,
#  1.801721025736721,
#  1.9828801945997383,
#  1.8709919842373945,
#  1.7429324711031935,
#  1.6339886679310816]

# %%
temp_l_m = []
for x in collection_acc_user:
    temp_l_m.append(max(x))

# %%
temp_l_m
# Out:
# [2.7853841580284713,
#  2.477749726324046,
#  2.8669496275585327,
#  2.7318557087139315,
#  2.761270378427103,
#  2.9654173366887515,
#  2.979888039013298,
#  2.8307172942649266,
#  3.2587243296976394,
#  3.0373924123727662]

# %%
# !pwd
# Out:
# /Users/prakanshulsaxena/GSoC

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v0 = [
("01866", 2.6802221738190273),
("02459", 2.497872271565231),
("01816", 3.306436198663057),
("03004", 2.758874554925905),
("03253", 2.770841575563543),
("01231", 2.65709886528189),
("00503", 3.324667890528944),
("02152", 2.9952022861768555),
("02015", 2.9115814322145397),
("01046", 4.437580692671861)
]

# %%
v1=[
("01866", 2.5164305253882837),
("02459", 2.432489834438962),
("01816", 3.403249714105662),
("03004", 3.202929947882497),
("03253", 2.9147102840192978),
("01231", 2.4346684358550803),
("00503", 3.717040883259224),
("02152", 2.406673200185266),
("02015", 3.358429300235631),
("01046", 3.5985025263507)
]

# %%
v2 = [
("01866", 3.2559404394021914),
("02459", 3.1085994039762768),
("01816", 3.8945127361071976),
("03004", 3.427761616240274),
("03253", 3.2215803834310432),
("01231", 3.224646591533223),
("00503", 2.8884257394336044),
("02152", 2.751313822259718),
("02015", 4.182966838161651),
("01046", 2.9256871207781368)
]

# %%
v3=[
("01866", 2.6842527770833087),
("02459", 2.9636542873053076),
("01816", 3.4115857536301366),
("03004", 3.6786488685583123),
("03253", 2.377670381371976),
("01231", 2.3823813702467374),
("00503", 2.907167072114339),
("02152", 2.6402980424759095),
("02015", 3.3320927276148304),
("01046", 3.1792654827649565)
]

# %%
v3b=[
("01866", 2.359041980553298),
("02459", 1.7700490726976932),
("01816", 2.323508330918378),
("03004", 2.6282637916209413),
("03253", 2.730605433921539),
("01231", 2.4009897263850717),
("00503", 1.9555042079851743),
("02152", 2.5229277123597793),
("02015", 3.179108235290938),
("01046", 3.4720301552610433)
]

# %%
v3TESTING=[
("01866", 2.9878722575678167),
("02459", 3.9157302726485903),
("01816", 2.4561961791545808),
("03004", 3.7487542521352615),
("03253", 2.7312079466624386),
("01231", 3.424836989763663),
("00503", 2.9398891777814593),
("02152", 3.3576426397902903),
("02015", 3.498317553223865),
("01046", 2.595843937479001)
]

# %%
v4=[
("01866", 3.528520975451089),
("02459", 2.693315394793253),
("01816", 2.4983583031936156),
("03004", 2.5030956073410904),
("03253", 2.5290804660005013),
("01231", 4.045135749882251),
("00503", 3.6552602666202807),
("02152", 3.1661391744268843),
("02015", 3.6880359770325786),
("01046", 3.2380852549028125)
]

# %%
v4b=[
("01866", 1.703244879826164),
("02459", 2.3250729028810344),
("01816", 2.104017186081759),
("03004", 3.012856986365518),
("03253", 2.859639681339617),
("01231", 3.0815840584818996),
("00503", 2.506946505991047),
("02152", 2.6473978503479376),
("02015", 2.6412614571439295),
("01046", 2.9613421177210935)
]

# %%
v4test = [
("01866", 2.498152895444813),
("02459", 3.6318632279220235),
("01816", 2.776874143197146),
("03004", 4.105573672854316),
("03253", 2.411723133442925),
("01231", 3.1572796947016357),
("00503", 3.5248155309982683),
("02152", 2.8021782147088885),
("02015", 4.053582161821229),
("01046", 2.99325623202723)
]

# %%
v5 = [
("01866", 2.369840309752965),
("02459", 2.7558760251315713),
("01816", 3.4741398251521947),
("03004", 2.448592722368178),
("03253", 2.5368539417797473),
("01231", 2.645758990653827),
("00503", 3.1835983004448973),
("02152", 2.7338989889129945),
("02015", 3.4960872660858335),
("01046", 3.502304082004525)
]

# %%
v5b = [
("01866", 2.1270445595720187),
("02459", 2.215472841199128),
("01816", 2.2933810214659367),
("03004", 2.7284460812848854),
("03253", 2.8392912301519164),
("01231", 3.0439436067525634),
("00503", 2.7709818777450774),
("02152", 2.650444455493486),
("02015", 3.401648564664241),
("01046", 3.5868419589546536)
]

# %%
vfinal_flipkey=[
("01866", 1.979857968452334),
("02459", 1.2900384637344922),
("01816", 1.5021182382914158),
("03004", 2.337483998771165),
("03253", 1.78057716893938),
("01231", 2.5685647322974168),
("00503", 1.9208865988004125),
("02152", 2.029771673539051),
("02015", 2.1835897141502056),
("01046", 2.342791367148116)
]

# %%
vfinal=[
("01866", 2.467796539728877),
("02459", 1.477261743943898),
("01816", 2.307085147181144),
("03004", 3.4120720291826014),
("03253", 2.9695970558580296),
("01231", 3.147174308173673),
("00503", 2.619672905089376),
("02152", 2.4960892153336567),
("02015", 3.0886467502950525),
("01046", 1.9048670821771125)
]

# %%
vfinalLRnoflip_flipkey=[
            ("01866", 0.7769615260756431),
            ("02459", 0.7475574636597919),
            ("01816", 1.6868913380556012),
            ("03004", 2.5595924697343913),
            ("03253", 1.529436609214951),
            ("01231", 2.844880781959935),
            ("00503", 2.1142411937550096),
            ("02152", 3.5611400304872802),
            ("02015", 1.7153874180664477),
            ("01046", 2.0876473433388694)
]

# %%
vfinalLRnoflip=[
("01866", 1.2557314836467801),
("02459", 1.6587392009675404),
("01816", 3.366299557387334),
("03004", 3.3063774755814177),
("03253", 2.769625505288301),
("01231", 2.9955979953034286),
("00503", 1.956337657524145),
("02152", 3.553503775336177),
("02015", 2.618535664908494),
("01046", 2.1688407203435958)
]

# %%
vfinalUnif=[
("01866", 1.8132797618099603),
("02459", 2.9843442595737377),
("01816", 2.745592240449352),
("03004", 2.946535586864891),
("03253", 3.313208305132287),
("01231", 2.6234445841472986),
("00503", 2.9656076234294932),
("02152", 3.836930710602909),
("02015", 3.3686418408666112),
("01046", 2.257174339617439)
]

# %%
collection_of_versions = [vfinal,vfinalLRnoflip_flipkey,vfinal_flipkey,vfinalUnif,vfinalLRnoflip,v5b,v4b,v3b,v4test,v5,v0,v4,v3,v3TESTING,v2,v1]

# %%
len(collection_of_versions)
# Out:
# 16

# %%
versions = ['vfinal','vfinalLRnoflip_flipkey','vfinal_flipkey','vfinalUnif','vfinalLRnoflip','v5b','v4b','v3b','v4test','v5','v0','v4','v3','v3TESTING','v2','v1']

# %%
collection_acc_user=[]
for i in range(10):
    collection_acc_user.append([vfinal[i][1],vfinalLRnoflip_flipkey[i][1],vfinal_flipkey[i][1],vfinalUnif[i][1],vfinalLRnoflip[i][1],v5b[i][1],v4b[i][1],v3b[i][1],v4test[i][1],v5[i][1],v0[i][1],v4[i][1],v3[i][1],v3TESTING[i][1],v2[i][1],v1[i][1]])

# %%
len(collection_acc_user)
# Out:
# 10

# %%
average_collection = []
for x in collection_of_versions:
    sum_pv = 0
    for y in x:
        sum_pv+=y[1]
    average_pv = sum_pv/len(x)
    average_collection.append(average_pv)

# %%
len(average_collection)
# Out:
# 16

# %%
# x-axis and y-axis values for plotting
idx = [i for i in range(1,17)]
  
plt.figure(figsize=(35, 32))
# Plotting x-axis and y-axis
plt.plot(idx, collection_acc_user[0],marker='.',color='red',linestyle='solid', markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[1],marker='.',color='green',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[2],marker='.',color='blue',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[3],marker='.',color='orange',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[4],marker='.',color='purple',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[5],marker='.',color='brown',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[6],marker='.',color='red',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[7],marker='.',color='green',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[8],marker='.',color='blue',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[9],marker='.',color='orange',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, average_collection,marker='.',color='black',linewidth=7,linestyle='solid',markersize=12,markerfacecolor='red',markeredgecolor='red')
 
# naming of x-axis and y-axis
plt.xlabel("Versions")
plt.ylabel("MED")

plt.xticks(idx, versions)
# plt.xticks(np.arange(0, len(x)+1, 5))
plt.yticks(np.arange(min(temp_l), max(temp_l_m),0.1))

plt.grid(color = 'black', linestyle = '-', linewidth = 0.2)

plt.title("All Versions with AVG")
plt.savefig('/Users/prakanshulsaxena/GSoC/Result_Visualisations/all_versions_split_first_unique_points_30_cv5.jpg')
plt.show()

# %%
temp_l = []
for x in collection_acc_user:
    temp_l.append(min(x))

# %%
temp_l
# Out:
# [0.7769615260756431,
#  0.7475574636597919,
#  1.5021182382914158,
#  2.337483998771165,
#  1.529436609214951,
#  2.3823813702467374,
#  1.9208865988004125,
#  2.029771673539051,
#  1.7153874180664477,
#  1.9048670821771125]

# %%
temp_l_m = []
for x in collection_acc_user:
    temp_l_m.append(max(x))

# %%
temp_l_m
# Out:
# [3.528520975451089,
#  3.9157302726485903,
#  3.8945127361071976,
#  4.105573672854316,
#  3.313208305132287,
#  4.045135749882251,
#  3.717040883259224,
#  3.836930710602909,
#  4.182966838161651,
#  4.437580692671861]

# %%
# !pwd
# Out:
# /Users/prakanshulsaxena/GSoC

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v0 = [
("01866", 2.777582854972578),
("02459", 3.124838217117154),
("01816", 3.0141451347472463),
("03004", 2.8819651401175306),
("03253", 3.065805546119221),
("01231", 2.535019834066278),
("00503", 3.7176322043470496),
("02152", 3.3456633333862267),
("02015", 3.465883511359654),
("01046", 3.0561159905080175)
]

# %%
v1=[
("01866", 3.2362782677314748),
("02459", 2.0572123430793567),
("01816", 3.0458918097611427),
("03004", 3.0530083616506065),
("03253", 3.126191637489977),
("01231", 2.7939083481074936),
("00503", 3.5279871705164303),
("02152", 3.584255214413059),
("02015", 2.8622717180441106),
("01046", 2.7280724486504693)
]

# %%
v2 = [
("01866", 3.7904915520771487),
("02459", 2.7064841640240207),
("01816", 3.6380851121088984),
("03004", 2.852541607749496),
("03253", 2.3734611082175845),
("01231", 3.2396421358863243),
("00503", 3.36869994199698),
("02152", 3.207482585653848),
("02015", 3.2942044400062347),
("01046", 2.6198422061382405)
]

# %%
v3=[
("01866", 2.5648611514046604),
("02459", 2.9171377671538514),
("01816", 2.5655600552457596),
("03004", 3.1021419154063428),
("03253", 3.193021062734839),
("01231", 3.8243089832229265),
("00503", 2.9965009122420634),
("02152", 3.3276700276734266),
("02015", 3.3384542533974617),
("01046", 3.2275283530706824)
]

# %%
v3b=[
("01866", 1.8483193614185174),
("02459", 2.128427936098783),
("01816", 2.4497508100221506),
("03004", 2.5846385814716815),
("03253", 2.810976178909076),
("01231", 3.1884413593012493),
("00503", 1.730862054229525),
("02152", 3.1309581007640777),
("02015", 3.623974365109991),
("01046", 3.842041761095212)
]

# %%
v3TESTING=[
("01866", 2.8480093085519744),
("02459", 3.2339177812922073),
("01816", 3.4240889669675325),
("03004", 2.9393025538727375),
("03253", 2.552282907686883),
("01231", 3.717452310165241),
("00503", 3.0079269101084343),
("02152", 3.2353144461419587),
("02015", 3.1060167423834386),
("01046", 3.2978397145835467)
]

# %%
v4=[
("01866", 2.351089022953106),
("02459", 2.5059482640940534),
("01816", 2.5671601317993438),
("03004", 3.970268897710115),
("03253", 4.369913736054062),
("01231", 2.850939665855004),
("00503", 3.9344230032663936),
("02152", 2.18549309438159),
("02015", 2.8437689333971647),
("01046", 3.3061343145085016)
]

# %%
v4b=[
("01866", 1.9607460921743565),
("02459", 2.612500320031136),
("01816", 2.5228146443613184),
("03004", 3.9141129362442837),
("03253", 3.5192627853255303),
("01231", 2.972397567998408),
("00503", 2.6890420189726676),
("02152", 3.05352585818208),
("02015", 3.1627018280757357),
("01046", 3.212457654419657)
]

# %%
v4test = [
("01866", 2.5792229529513397),
("02459", 3.0077403159069718),
("01816", 3.433693261691496),
("03004", 2.917314933914623),
("03253", 2.7538162780863096),
("01231", 2.5536756119105797),
("00503", 3.606025608668386),
("02152", 3.0135299839698115),
("02015", 3.4372918132410337),
("01046", 2.8449023292584834)
]

# %%
v5 = [
("01866", 2.9288957658448913),
("02459", 2.8696947627776948),
("01816", 2.7148157692446375),
("03004", 2.6721706626516712),
("03253", 2.3450434402051155),
("01231", 3.133950124241295),
("00503", 3.063081790553222),
("02152", 3.499453771663104),
("02015", 3.288891562024794),
("01046", 3.129623067978429)
]

# %%
v5b = [
("01866", 1.9871454213474857),
("02459", 2.263021396646463),
("01816", 2.2988268109337953),
("03004", 3.318922449025778),
("03253", 2.9585820794064195),
("01231", 2.7902321222603232),
("00503", 2.404346498225787),
("02152", 2.6403642365689324),
("02015", 3.354863992683482),
("01046", 3.152617326350013)
]

# %%
vfinal_flipkey=[
("01866", 1.3667191944192878),
("02459", 1.1558575745596273),
("01816", 1.3801726429835335),
("03004", 2.6790322573778464),
("03253", 1.3935748373774222),
("01231", 1.6412907011837354),
("00503", 2.8089045555928376),
("02152", 3.516557300480252),
("02015", 2.550796762394114),
("01046", 2.291041928668669)
]

# %%
vfinal=[
("01866", 1.035223014223329),
("02459", 1.435274397961507),
("01816", 3.0781202229744156),
("03004", 2.930848187251331),
("03253", 2.1684007451283613),
("01231", 2.7744110349697704),
("00503", 2.7720619925786933),
("02152", 4.532842610431851),
("02015", 3.7410691047976883),
("01046", 1.7901766800698151)
]

# %%
vfinalLRnoflip_flipkey=[
("01866", 0.9065178891784805),
("02459", 0.9814325990795036),
("01816", 1.5690966542344298),
("03004", 2.443430517077219),
("03253", 1.4101983925354402),
("01231", 1.8863344482504343),
("00503", 2.634162497903608),
("02152", 3.8514668309927425),
("02015", 2.8636038185458137),
("01046", 2.271518372664654)
]

# %%
vfinalLRnoflip=[
("01866", 2.0321825600668078),
("02459", 1.7257258328653287),
("01816", 3.0780710723878),
("03004", 3.4744517164383417),
("03253", 2.55849682247128),
("01231", 3.238618774944846),
("00503", 1.8419235162794696),
("02152", 2.9972506078196273),
("02015", 3.4602743989432665),
("01046", 2.838226533200709)
]

# %%
vfinalUnif=[
("01866", 1.943556966395098),
("02459", 2.821164304963056),
("01816", 3.4488943650990995),
("03004", 2.728187894486492),
("03253", 3.2240435271915135),
("01231", 2.6078538074879374),
("00503", 4.3583865505851245),
("02152", 3.5920387793868986),
("02015", 3.661169059075549),
("01046", 2.791437247425146)
]

# %%
collection_of_versions = [vfinal,vfinalLRnoflip_flipkey,vfinal_flipkey,vfinalUnif,vfinalLRnoflip,v5b,v4b,v3b,v4test,v5,v0,v4,v3,v3TESTING,v2,v1]

# %%
len(collection_of_versions)
# Out:
# 16

# %%
versions = ['vfinal','vfinalLRnoflip_flipkey','vfinal_flipkey','vfinalUnif','vfinalLRnoflip','v5b','v4b','v3b','v4test','v5','v0','v4','v3','v3TESTING','v2','v1']

# %%
collection_acc_user=[]
for i in range(10):
    collection_acc_user.append([vfinal[i][1],vfinalLRnoflip_flipkey[i][1],vfinal_flipkey[i][1],vfinalUnif[i][1],vfinalLRnoflip[i][1],v5b[i][1],v4b[i][1],v3b[i][1],v4test[i][1],v5[i][1],v0[i][1],v4[i][1],v3[i][1],v3TESTING[i][1],v2[i][1],v1[i][1]])

# %%
len(collection_acc_user)
# Out:
# 10

# %%
average_collection = []
for x in collection_of_versions:
    sum_pv = 0
    for y in x:
        sum_pv+=y[1]
    average_pv = sum_pv/len(x)
    average_collection.append(average_pv)

# %%
len(average_collection)
# Out:
# 16

# %%
# x-axis and y-axis values for plotting
idx = [i for i in range(1,17)]
  
plt.figure(figsize=(35, 32))
# Plotting x-axis and y-axis
plt.plot(idx, collection_acc_user[0],marker='.',color='red',linestyle='solid', markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[1],marker='.',color='green',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[2],marker='.',color='blue',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[3],marker='.',color='orange',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[4],marker='.',color='purple',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[5],marker='.',color='brown',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[6],marker='.',color='red',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[7],marker='.',color='green',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[8],marker='.',color='blue',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[9],marker='.',color='orange',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, average_collection,marker='.',color='black',linewidth=7,linestyle='solid',markersize=12,markerfacecolor='red',markeredgecolor='red')
 
# naming of x-axis and y-axis
plt.xlabel("Versions")
plt.ylabel("MED")

plt.xticks(idx, versions)
# plt.xticks(np.arange(0, len(x)+1, 5))
plt.yticks(np.arange(min(temp_l), max(temp_l_m),0.1))

plt.grid(color = 'black', linestyle = '-', linewidth = 0.2)

plt.title("All Versions with AVG")
plt.savefig('/Users/prakanshulsaxena/GSoC/Result_Visualisations/all_versions_split_first_unique_points_30_cv3_her.jpg')
plt.show()

# %%
temp_l = []
for x in collection_acc_user:
    temp_l.append(min(x))

# %%
temp_l
# Out:
# [0.9065178891784805,
#  0.9814325990795036,
#  1.3801726429835335,
#  2.443430517077219,
#  1.3935748373774222,
#  1.6412907011837354,
#  1.730862054229525,
#  2.18549309438159,
#  2.550796762394114,
#  1.7901766800698151]

# %%
temp_l_m = []
for x in collection_acc_user:
    temp_l_m.append(max(x))

# %%
temp_l_m
# Out:
# [3.7904915520771487,
#  3.2339177812922073,
#  3.6380851121088984,
#  3.970268897710115,
#  4.369913736054062,
#  3.8243089832229265,
#  4.3583865505851245,
#  4.532842610431851,
#  3.7410691047976883,
#  3.842041761095212]

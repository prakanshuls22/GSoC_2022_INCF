# %%
# !pwd
# Out:
# /Users/prakanshulsaxena/GSoC

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v0 = [
("01866", 2.6392044407202766),
("02459", 2.2924226047657887),
("01816", 2.6057373556727463),
("03004", 2.434287872715376),
("03253", 2.704841986671308),
("01231", 3.044062148333973),
("00503", 2.867316628634645),
("02152", 2.7458232183709566),
("02015", 2.969245882778065),
("01046", 2.963995179998141)
]

# %%
v1=[
("01866", 2.7379516762780285),
("02459", 2.1613522535060636),
("01816", 2.5770601737625043),
("03004", 2.5363750430338126),
("03253", 2.746601287106334),
("01231", 2.9750248184727135),
("00503", 3.034209791465915),
("02152", 2.5985931049302256),
("02015", 2.92371864093527),
("01046", 3.060503209667352)
]

# %%
v2 = [
("01866", 2.7902423005618893),
("02459", 2.249879151044607),
("01816", 2.598787868575627),
("03004", 2.490901592636529),
("03253", 2.713890669043895),
("01231", 2.861006776341689),
("00503", 2.702871291622102),
("02152", 2.6566724126624583),
("02015", 2.991316226617329),
("01046", 2.922828645434651)
]

# %%
v3=[
("01866", 2.7269327269490304),
("02459", 1.9371591208634642),
("01816", 2.684173764207135),
("03004", 2.2857222701188364),
("03253", 2.2991700497594048),
("01231", 2.823614753013579),
("00503", 2.8534210295571305),
("02152", 2.600883880692076),
("02015", 3.2063571277905565),
("01046", 2.9160764801074386)
]

# %%
v3b=[
("01866", 1.673165008246614),
("02459", 1.837671148038273),
("01816", 2.231890480467928),
("03004", 1.8816068178366439),
("03253", 2.616591595818845),
("01231", 2.3428539685962195),
("00503", 2.3591428903575276),
("02152", 2.2232548150666465),
("02015", 2.830054190336818),
("01046", 2.696477165862553)
]

# %%
v3TESTING=[
("01866", 2.620609817349671),
("02459", 1.9021190120206906),
("01816", 2.7596346704133667),
("03004", 2.409807323601317),
("03253", 2.4267490242648435),
("01231", 3.052263431162721),
("00503", 2.689597414065618),
("02152", 2.7668389452892246),
("02015", 3.029922651852608),
("01046", 2.993090014175752)
]

# %%
v4=[
("01866", 2.5160131857020316),
("02459", 2.059786613244915),
("01816", 2.8265994408670228),
("03004", 2.363168717463128),
("03253", 2.289622187793096),
("01231", 2.9009672753514755),
("00503", 2.85013097806333),
("02152", 2.6594817443286356),
("02015", 3.1512679076018464),
("01046", 2.9492669579543014)
]

# %%
v4b=[
("01866", 1.8853265785384072),
("02459", 1.8451303655721614),
("01816", 2.1720835495766115),
("03004", 2.395925717668433),
("03253", 2.6833792477278338),
("01231", 2.57040882234018),
("00503", 2.4237689360638246),
("02152", 2.3944284522616757),
("02015", 2.805148057768543),
("01046", 2.5593720157055904)
]

# %%
v4test = [
("01866", 2.5495337334825705),
("02459", 2.0696010605776936),
("01816", 2.8019568982104577),
("03004", 2.382658449990143),
("03253", 2.1921768107086246),
("01231", 2.7542329723034475),
("00503", 2.9654073846640783),
("02152", 2.753167086661143),
("02015", 3.0482078619848583),
("01046", 2.974184024021775)
]

# %%
v5 = [
("01866", 2.451143557477532),
("02459", 2.219701613193827),
("01816", 2.805111320855697),
("03004", 2.2503976874255387),
("03253", 2.1894366149072746),
("01231", 2.8284265802752704),
("00503", 2.8998275991948237),
("02152", 2.8245827220171713),
("02015", 3.0511208337721665),
("01046", 3.044894944580801)
]

# %%
v5b = [
("01866", 1.7066467482429102),
("02459", 1.8930242205034866),
("01816", 2.2300243064933265),
("03004", 2.1179486349627505),
("03253", 2.638053413709113),
("01231", 2.189272949216049),
("00503", 2.3429876208227993),
("02152", 2.2507055244072696),
("02015", 2.8320521023882748),
("01046", 2.592251527489048)
]

# %%
vfinal_flipkey=[
("01866", 1.0473974233646617),
("02459", 0.9655047599743674),
("01816", 1.1801433288467937),
("03004", 1.79012565581091),
("03253", 1.3989735323711285),
("01231", 1.6597512039599176),
("00503", 2.163663339751732),
("02152", 1.8816201584443983),
("02015", 1.9767222562837876),
("01046", 1.5533587433680458)
]

# %%
vfinal=[
("01866", 1.2502674980043122),
("02459", 1.2838914987530847),
("01816", 2.677923106168054),
("03004", 2.5431903079786204),
("03253", 1.7136077598264499),
("01231", 2.4424278086112454),
("00503", 2.4593138011444817),
("02152", 2.109397252809948),
("02015", 3.022829945366199),
("01046", 1.9360187171820884)
]

# %%
vfinalLRnoflip_flipkey=[
("01866", 0.9598022279487516),
("02459", 0.9294862105382238),
("01816", 1.4349592601094785),
("03004", 1.5960282264837846),
("03253", 1.1636365392767787),
("01231", 1.8198328724564743),
("00503", 2.085396790763805),
("02152", 2.2415705259197347),
("02015", 1.9030757665242084),
("01046", 1.7196485603500549)
]

# %%
vfinalLRnoflip=[
("01866", 1.1091367810975243),
("02459", 1.5475360861029657),
("01816", 2.791738528635366),
("03004", 2.5788831283341827),
("03253", 2.0053998820018966),
("01231", 2.3999260878483986),
("00503", 2.3343593535365548),
("02152", 2.4596162970516144),
("02015", 2.9742114915597524),
("01046", 1.9523200125277569)
]

# %%
vfinalUnif=[
("01866", 1.7024311430909167),
("02459", 2.283282554122414),
("01816", 2.6808858272821703),
("03004", 2.2280758081280787),
("03253", 2.0025564853326636),
("01231", 2.1983558511264567),
("00503", 2.52689738501987),
("02152", 2.5340819717920358),
("02015", 2.7980384936570943),
("01046", 2.2934490143642012)
]

# %%
collection_of_versions = [vfinal,vfinalLRnoflip_flipkey,vfinal_flipkey,vfinalUnif,vfinalLRnoflip,v5b,v4b,v3b,v4test,v5,v0,v4,v3,v3TESTING,v2,v1]

# %%
len(collection_of_versions)
# Out:
# 16

# %%
versions = ['vfinal','vfinalLRnoflip_flipkey','vfinal_flipkey','vfinalUnif','vfinalLRnoflip','v5b','v4b','v3b','v4test','v5','v0','v4','v3','v3TESTING','v2','v1']

# %%
collection_acc_user=[]
for i in range(10):
    collection_acc_user.append([vfinal[i][1],vfinalLRnoflip_flipkey[i][1],vfinal_flipkey[i][1],vfinalUnif[i][1],vfinalLRnoflip[i][1],v5b[i][1],v4b[i][1],v3b[i][1],v4test[i][1],v5[i][1],v0[i][1],v4[i][1],v3[i][1],v3TESTING[i][1],v2[i][1],v1[i][1]])

# %%
len(collection_acc_user)
# Out:
# 10

# %%
average_collection = []
for x in collection_of_versions:
    sum_pv = 0
    for y in x:
        sum_pv+=y[1]
    average_pv = sum_pv/len(x)
    average_collection.append(average_pv)

# %%
len(average_collection)
# Out:
# 16

# %%
# x-axis and y-axis values for plotting
idx = [i for i in range(1,17)]
  
plt.figure(figsize=(35, 32))
# Plotting x-axis and y-axis
plt.plot(idx, collection_acc_user[0],marker='.',color='red',linestyle='solid', markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[1],marker='.',color='green',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[2],marker='.',color='blue',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[3],marker='.',color='orange',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[4],marker='.',color='purple',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[5],marker='.',color='brown',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[6],marker='.',color='red',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[7],marker='.',color='green',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[8],marker='.',color='blue',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[9],marker='.',color='orange',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, average_collection,marker='.',color='black',linewidth=7,linestyle='solid',markersize=12,markerfacecolor='red',markeredgecolor='red')
 
# naming of x-axis and y-axis
plt.xlabel("Versions")
plt.ylabel("MED")

plt.xticks(idx, versions)
# plt.xticks(np.arange(0, len(x)+1, 5))
plt.yticks(np.arange(min(temp_l), max(temp_l_m),0.1))

plt.grid(color = 'black', linestyle = '-', linewidth = 0.2)

plt.title("All Versions with AVG")
plt.savefig('/Users/prakanshulsaxena/GSoC/Result_Visualisations/all_versions_3_fold_split_first_cv3.jpg')
plt.show()

# %%
temp_l = []
for x in collection_acc_user:
    temp_l.append(min(x))

# %%
temp_l
# Out:
# [0.9598022279487516,
#  0.9294862105382238,
#  1.1801433288467937,
#  1.5960282264837846,
#  1.1636365392767787,
#  1.6597512039599176,
#  2.085396790763805,
#  1.8816201584443983,
#  1.9030757665242084,
#  1.5533587433680458]

# %%
temp_l_m = []
for x in collection_acc_user:
    temp_l_m.append(max(x))

# %%
temp_l_m
# Out:
# [2.7902423005618893,
#  2.2924226047657887,
#  2.8265994408670228,
#  2.5788831283341827,
#  2.746601287106334,
#  3.052263431162721,
#  3.034209791465915,
#  2.8245827220171713,
#  3.2063571277905565,
#  3.060503209667352]

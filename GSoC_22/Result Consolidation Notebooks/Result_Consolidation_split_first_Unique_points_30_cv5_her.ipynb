# %%
# !pwd
# Out:
# /Users/prakanshulsaxena/GSoC

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v0 = [
("01866", 3.5341225244837493),
("02459", 2.9464705235314925),
("01816", 3.289045992822625),
("03004", 2.198867737786311),
("03253", 2.9314727110986163),
("01231", 3.327856591111138),
("00503", 3.171193027778285),
("02152", 3.275372166975138),
("02015", 3.44950484926842),
("01046", 3.6032269746575816)
]

# %%
v1=[
("01866", 3.4654961077490336),
("02459", 3.6333837395506805),
("01816", 3.3978388820168877),
("03004", 2.5151646128560454),
("03253", 2.7749400716725603),
("01231", 2.781278450044766),
("00503", 3.684877448481913),
("02152", 3.4216864575291837),
("02015", 3.096058777867118),
("01046", 3.9825141314341144)
]

# %%
v2 = [
            ("01866", 1.9768036773196347),
            ("02459", 2.4850711816747997),
            ("01816", 2.853510982947598),
            ("03004", 2.420723427878114),
            ("03253", 3.431422456086696),
            ("01231", 2.9030021724208384),
            ("00503", 3.680230571853538),
            ("02152", 3.4047590094978424),
            ("02015", 2.9432622589546837),
            ("01046", 3.3128910203869335)
]

# %%
v3=[
("01866", 1.7159463314498908),
("02459", 3.196790019148375),
("01816", 3.0340090440421568),
("03004", 3.4079587528092374),
("03253", 2.20334758177003),
("01231", 3.225037635838118),
("00503", 3.219625373274735),
("02152", 2.655596603087708),
("02015", 3.5184522848693374),
("01046", 3.821939453758496)
]

# %%
v3b=[
("01866", 2.2460133449803954),
("02459", 1.9924342387780694),
("01816", 2.3051859881666914),
("03004", 3.24424395923549),
("03253", 4.1146102925233965),
("01231", 2.918499524159074),
("00503", 2.758419564202007),
("02152", 2.196554381275924),
("02015", 3.6538493911696057),
("01046", 2.752658332763561)
]

# %%
v3TESTING=[
("01866", 2.7140157484132406),
("02459", 1.9231154425938881),
("01816", 3.260292511861773),
("03004", 2.6939386380982944),
("03253", 2.753657361205962),
("01231", 2.866230962645133),
("00503", 3.582779110422747),
("02152", 3.671818838481891),
("02015", 3.953929018750949),
("01046", 2.819677828241572)
]

# %%
v4=[
("01866", 3.137015279796073),
("02459", 2.665096887438603),
("01816", 2.6850655270082413),
("03004", 1.9321181106975511),
("03253", 2.868448957733438),
("01231", 2.629626812200944),
("00503", 3.280275425864165),
("02152", 2.898104900691877),
("02015", 3.065032458178066),
("01046", 2.5495240028054393)
]

# %%
v4b=[
("01866", 2.2101425306713396),
("02459", 1.8794931461766338),
("01816", 2.417647075389898),
("03004", 3.447458969825407),
("03253", 2.776794174348853),
("01231", 2.8858964318325686),
("00503", 2.9407081888658713),
("02152", 2.8257008652758393),
("02015", 2.863798862551098),
("01046", 2.8608811449048157)
]

# %%
v4test = [
("01866", 2.8444408671372923),
("02459", 2.49318374609408),
("01816", 2.6543559353567496),
("03004", 3.5367166373982624),
("03253", 2.048448053128763),
("01231", 3.1974003706611773),
("00503", 3.2855426259224023),
("02152", 3.574873317483714),
("02015", 4.231508337928194),
("01046", 3.1522605582367995)
]

# %%
v5 = [
("01866", 3.5544117813259466),
("02459", 2.685902419321656),
("01816", 2.683598866751072),
("03004", 2.838829771777491),
("03253", 2.6437258720316397),
("01231", 4.09439226188617),
("00503", 3.1269265825724673),
("02152", 3.5011363718023203),
("02015", 3.110996720070979),
("01046", 3.332785252403089)
]

# %%
v5b = [
("01866", 1.9414598752204668),
("02459", 2.2693552462516378),
("01816", 2.7810369825887804),
("03004", 2.9781065032826017),
("03253", 3.0999065121218874),
("01231", 3.2079267968228673),
("00503", 3.146761643393735),
("02152", 2.407698443836095),
("02015", 1.8624732969891875),
("01046", 2.8936885074008454)
]

# %%
vfinal_flipkey=[
("01866", 1.6284819437946356),
("02459", 1.2272747002323077),
("01816", 1.4773144550153778),
("03004", 3.135904359430842),
("03253", 1.9000955972637041),
("01231", 1.9253197013875676),
("00503", 3.5036562692798006),
("02152", 2.418770213031966),
("02015", 2.4759479262117745),
("01046", 2.2914079487315067)
]

# %%
vfinal=[
("01866", 1.2715661884011107),
("02459", 1.3632625491714014),
("01816", 2.560463659619766),
("03004", 3.058217788691717),
("03253", 2.5057571598827253),
("01231", 3.4361990765864094),
("00503", 3.9278474576433857),
("02152", 3.518300443466988),
("02015", 3.620886562169995),
("01046", 2.036781054041575)
]

# %%
vfinalLRnoflip_flipkey=[
("01866", 0.7769615260756431),
("02459", 0.7475574636597919),
("01816", 1.6868913380556012),
("03004", 2.5595924697343913),
("03253", 1.529436609214951),
("01231", 2.844880781959935),
("00503", 2.1142411937550096),
("02152", 3.5611400304872802),
("02015", 1.7153874180664477),
("01046", 2.0876473433388694)
]

# %%
vfinalLRnoflip=[
("01866", 1.360402166772991),
("02459", 1.7431382345021522),
("01816", 3.182485280690312),
("03004", 2.857494958135541),
("03253", 2.3892353305374594),
("01231", 4.008579464352614),
("00503", 3.2925440718236314),
("02152", 3.093366750257198),
("02015", 2.7058048534618266),
("01046", 2.271914395142328)
]

# %%
vfinalUnif=[
("01866", 2.622690396283806),
("02459", 2.946042045029684),
("01816", 4.360258972222101),
("03004", 2.383200439973985),
("03253", 2.280872477290628),
("01231", 1.8563262139560592),
("00503", 2.6026292285103243),
("02152", 3.1029168787774886),
("02015", 2.8868530411844966),
("01046", 1.9223755909624165)
]

# %%
collection_of_versions = [vfinal,vfinalLRnoflip_flipkey,vfinal_flipkey,vfinalUnif,vfinalLRnoflip,v5b,v4b,v3b,v4test,v5,v0,v4,v3,v3TESTING,v2,v1]

# %%
len(collection_of_versions)
# Out:
# 16

# %%
versions = ['vfinal','vfinalLRnoflip_flipkey','vfinal_flipkey','vfinalUnif','vfinalLRnoflip','v5b','v4b','v3b','v4test','v5','v0','v4','v3','v3TESTING','v2','v1']

# %%
collection_acc_user=[]
for i in range(10):
    collection_acc_user.append([vfinal[i][1],vfinalLRnoflip_flipkey[i][1],vfinal_flipkey[i][1],vfinalUnif[i][1],vfinalLRnoflip[i][1],v5b[i][1],v4b[i][1],v3b[i][1],v4test[i][1],v5[i][1],v0[i][1],v4[i][1],v3[i][1],v3TESTING[i][1],v2[i][1],v1[i][1]])

# %%
len(collection_acc_user)
# Out:
# 10

# %%
average_collection = []
for x in collection_of_versions:
    sum_pv = 0
    for y in x:
        sum_pv+=y[1]
    average_pv = sum_pv/len(x)
    average_collection.append(average_pv)

# %%
len(average_collection)
# Out:
# 16

# %%
# x-axis and y-axis values for plotting
idx = [i for i in range(1,17)]
  
plt.figure(figsize=(35, 32))
# Plotting x-axis and y-axis
plt.plot(idx, collection_acc_user[0],marker='.',color='red',linestyle='solid', markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[1],marker='.',color='green',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[2],marker='.',color='blue',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[3],marker='.',color='orange',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[4],marker='.',color='purple',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[5],marker='.',color='brown',linestyle='solid',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[6],marker='.',color='red',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[7],marker='.',color='green',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[8],marker='.',color='blue',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, collection_acc_user[9],marker='.',color='orange',linestyle='dashed',markersize=10,markerfacecolor='black',markeredgecolor='black')
plt.plot(idx, average_collection,marker='.',color='black',linewidth=7,linestyle='solid',markersize=12,markerfacecolor='red',markeredgecolor='red')
 
# naming of x-axis and y-axis
plt.xlabel("Versions")
plt.ylabel("MED")

plt.xticks(idx, versions)
# plt.xticks(np.arange(0, len(x)+1, 5))
plt.yticks(np.arange(min(temp_l), max(temp_l_m),0.1))

plt.grid(color = 'black', linestyle = '-', linewidth = 0.2)

plt.title("All Versions with AVG")
plt.savefig('/Users/prakanshulsaxena/GSoC/Result_Visualisations/all_versions_split_first_unique_points_30_cv5_her.jpg')
plt.show()

# %%
temp_l = []
for x in collection_acc_user:
    temp_l.append(min(x))

# %%
temp_l
# Out:
# [0.7769615260756431,
#  0.7475574636597919,
#  1.4773144550153778,
#  1.9321181106975511,
#  1.529436609214951,
#  1.8563262139560592,
#  2.1142411937550096,
#  2.196554381275924,
#  1.7153874180664477,
#  1.9223755909624165]

# %%
temp_l_m = []
for x in collection_acc_user:
    temp_l_m.append(max(x))

# %%
temp_l_m
# Out:
# [3.5544117813259466,
#  3.6333837395506805,
#  4.360258972222101,
#  3.5367166373982624,
#  4.1146102925233965,
#  4.09439226188617,
#  3.9278474576433857,
#  3.671818838481891,
#  4.231508337928194,
#  3.9825141314341144]
